# %% [markdown]
# <a href="https://colab.research.google.com/github/harshalmogre267-boop/harshalmogre/blob/main/salary_prediction_using_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/ybifoundation/Dataset/main/Salary%20Data.csv')

# %%
df.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
df.isnull().sum()
# Out:
# Experience Years    0
# Salary              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (40, 2)

# %%
df.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
import matplotlib.pyplot as plt

# %%
x=df[['Experience Years']]
y=df['Salary']
plt.figure(figsize=(10,5))
plt.scatter(x,y)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=2529)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((32, 1), (32,), (8, 1), (8,))

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)*100
# Out:
# 95.33748430623191

# %%
year=float(input("enter your year fo experience:"))
lr.predict([[7]])
# Out:
# enter your year fo experience:7
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([92132.2431092])

# %%
lr.intercept_
# Out:
# np.float64(26344.85810217697)

# %%
lr.coef_
# Out:
# array([9398.19785815])

# %%
x=df[['Experience Years']]
y=df['Salary']
plt.figure(figsize=(10,5))
plt.scatter(x,y)
plt.plot(x,lr.predict(x),color='red')
plt. xlabel('experience year')
plt.ylabel('salary')
plt.show()
